# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rc('font', family = 'AppleGothic')

# %%
CHART_NAME = 'seabornTest'
cnt, PNG, UNDERBAR = 0, '.png', '_'

def FileSave():
    global cnt
    cnt += 1
    savefile = CHART_NAME + UNDERBAR + str(cnt).zfill(2) + PNG
    plt.savefig(savefile, dpi=400)
    print(savefile + ' 파일이 저장되었습니다.')
# end def FileSave():

# %%
filename = '/Users/seohuiwon/Desktop/School/2023/pythonpratice/DataVisualization/소상공인시장진흥공단_상가(상권)정보_서울_202212.csv'
plt.style.use('ggplot') # 'ggplot' 형식의 스타일을 사용합니다.
# plt.style.use('Solarize_Light2')

# %%
df = pd.read_csv(filename, encoding='UTF-8')

# %%
df.head()
# Out:
#      상가업소번호         상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드   상권업종중분류명  \
# 0  23324279       제중건강원  NaN         D       소매       D10    건강/미용식품
# 1  24525909       민속악기사  NaN         D       소매       D04  취미/오락관련소매
# 2  24715368       태평양진주  NaN         D       소매       D26   시계/귀금속소매
# 3  15554136  김선희꼼꼼국어교습소  NaN         R    학문/교육       R01  학원-보습교습입시
# 4  17174175         비지트  NaN         Q       음식       Q01         한식
#
#   상권업종소분류코드   상권업종소분류명 표준산업분류코드  ...                     건물관리번호     건물명  \
# 0    D10A07        건강원   G47216  ...  1156010600100410002034626     NaN
# 1    D04A09       악기판매   G47593  ...  1120012200101420011000227     NaN
# 2    D26A01     시계/귀금속   G47830  ...  1111015200100440000000001  금사랑투빌딩
# 3    R01A01      학원-입시   P85501  ...  1171011100101970003017195     NaN
# 4    Q01A01  한식/백반/한정식   I56111  ...  1165010100108540018009586   상랑의빌딩
#
#                      도로명주소   구우편번호   신우편번호  동정보  층정보  호정보          경도  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 377724 entries, 0 to 377723
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     377724 non-null  int64
#  1   상호명        377724 non-null  object
#  2   지점명        63169 non-null   object
#  3   상권업종대분류코드  377724 non-null  object
#  4   상권업종대분류명   377724 non-null  object
#  5   상권업종중분류코드  377724 non-null  object
#  6   상권업종중분류명   377724 non-null  object
#  7   상권업종소분류코드  377724 non-null  object
#  8   상권업종소분류명   377724 non-null  object
#  9   표준산업분류코드   351543 non-null  object
#  10  표준산업분류명    351543 non-null  object
#  11  시도코드       377724 non-null  int64
#  12  시도명        377724 non-null  object
#  13  시군구코드      377724 non-null  int64
#  14  시군구명       377724 non-null  object
#  15  행정동코드      377724 non-null  int64
#  16  행정동명       377724 non-null  object
#  17  법정동코드      377724 non-null  int64
#  18  법정동명       377724 non-null  object
# ...

# %%
df.describe()
# Out:
#              상가업소번호      시도코드          시군구코드         행정동코드         법정동코드  \
# count  3.777240e+05  377724.0  377724.000000  3.777240e+05  3.777240e+05
# mean   1.931288e+07      11.0   11448.650165  1.144927e+09  1.144876e+09
# std    4.230363e+06       0.0     196.721436  1.967098e+07  1.967143e+07
# min    2.896730e+06      11.0   11110.000000  1.111052e+09  1.111010e+09
# 25%    1.677527e+07      11.0   11260.000000  1.126066e+09  1.126010e+09
# 50%    1.837565e+07      11.0   11470.000000  1.147058e+09  1.147010e+09
# 75%    2.297129e+07      11.0   11650.000000  1.165052e+09  1.165010e+09
# max    2.852486e+07      11.0   11740.000000  1.174070e+09  1.174011e+09
#
#                지번코드        대지구분코드          지번본번지          지번부번지         도로명코드  \
# count  3.777240e+05  377724.00000  377724.000000  299122.000000  3.777240e+05
# mean   1.144876e+18       1.00086     422.756311      35.632926  1.144901e+11
# ...

# %%
df.tail(50)
# Out:
#           상가업소번호                         상호명     지점명 상권업종대분류코드  상권업종대분류명  \
# 377674  19082796                        신선포차     NaN         Q        음식
# 377675  19082996                       라떼센세이     NaN         F     생활서비스
# 377676  19083187  하수구싱크대변기배관막힘역류막혔을때뚫음고압세척업체     NaN         D        소매
# 377677  19070658                         수건축     NaN         L       부동산
# 377678  19070852                        은꼬유통     NaN         D        소매
# 377679  19072434                      우성산업환경     NaN         F     생활서비스
# 377680  19072638                     원조왕십리곱창     NaN         Q        음식
# 377681  19073422                      영리치솔루션     NaN         F     생활서비스
# 377682  19073616                     힐리HILLI     NaN         Q        음식
# 377683  19073621                         잭프룻     NaN         F     생활서비스
# 377684  19074010                   오늘교육원협동조합     NaN         F     생활서비스
# 377685  19074020                        행복공방     NaN         D        소매
# ...

# %%
df
# Out:
#           상가업소번호         상호명   지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드   상권업종중분류명  \
# 0       23324279       제중건강원   NaN         D       소매       D10    건강/미용식품
# 1       24525909       민속악기사   NaN         D       소매       D04  취미/오락관련소매
# 2       24715368       태평양진주   NaN         D       소매       D26   시계/귀금속소매
# 3       15554136  김선희꼼꼼국어교습소   NaN         R    학문/교육       R01  학원-보습교습입시
# 4       17174175         비지트   NaN         Q       음식       Q01         한식
# ...          ...         ...   ...       ...      ...       ...        ...
# 377719  19079387   향나무참숯장어나라   NaN         Q       음식       Q01         한식
# 377720  19079580    에이치에스컨설팅   NaN         L      부동산       L01      부동산중개
# 377721  19079781       크린에이드  가양역점         F    생활서비스       F02   세탁/가사서비스
# 377722  19080385           멍   NaN         D       소매       D09   애견/애완/동물
# 377723  19080785       써니뷰티샵   NaN         F    생활서비스       F01    이/미용/건강
#
# ...

# %%
DF = pd.read_csv("LOCAL_PEOPLE_GU_2022.csv", encoding = 'cp949')

# %%
DF
# Out:
#            기준일ID  시간대구분  자치구코드       총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0       20220101      0  11110  198013.1166      4873.9724        2875.5716
# 1       20220101      0  11140  163439.6365      4588.8045        1754.1373
# 2       20220101      0  11170  252165.9659      7338.0378        3621.6062
# 3       20220101      0  11200  312343.4234     11468.7636        4805.9768
# 4       20220101      0  11215  348524.3239     10212.5621        5475.5993
# ...          ...    ...    ...          ...            ...              ...
# 218995  20221231     23  11620  468533.2179     11551.3074        5620.8956
# 218996  20221231     23  11650  464794.4332     20247.1960       10900.8345
# 218997  20221231     23  11680  626217.7021     24272.7828       15790.4802
# 218998  20221231     23  11710  726058.1872     31134.3399       15478.9444
# 218999  20221231     23  11740  515174.1517     20892.5856       11790.0818
#
# ...
